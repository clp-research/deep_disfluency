# %%
#Notebook to analyse different tags and their progression, plotting them!

# %%
# %matplotlib inline
import sys
sys.path.append("../")

# %%
from analysis_util import extract_accuracies_from_file, accuracyCurvePlot

# %%
#the classes of interest
learningCurveDict = {"<e/>" : [],
                     "<rm-1/><rpEndSub/>" : [],
                     "<rm-2/><rpMid/>" : [],
                     "<rm-3/><rpMid/>" : [],
                     "<rm-4/><rpMid/>" : []
                     }


extract_accuracies_from_file("../../../experiments/results/tag_accuracies/027.csv", learningCurveDict)

# %%
accuracyCurvePlot(learningCurveDict,49,'EMNLPgraph.pdf',upperlimit=1.0)
# Out:
# plotting learning curve
# 5
