# %%
# !pip install ibm_watson
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting ibm_watson
#   Using cached ibm-watson-6.0.0.tar.gz (338 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /anaconda2/bin/python /anaconda2/lib/python2.7/site-packages/pip/_vendor/pep517/_in_process.py get_requires_for_build_wheel /var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/tmpaF8Rox
#        cwd: /private/var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/pip-install-sOwaSg/ibm-watson
#   Complete output (16 lines):
#   Traceback (most recent call last):
#     File "/anaconda2/lib/python2.7/site-packages/pip/_vendor/pep517/_in_process.py", line 280, in <module>
#       main()
#     File "/anaconda2/lib/python2.7/site-packages/pip/_vendor/pep517/_in_process.py", line 263, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/anaconda2/lib/python2.7/site-packages/pip/_vendor/pep517/_in_process.py", line 114, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/private/var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/pip-build-env-_e3tGk/overlay/lib/python2.7/site-packages/setuptools/build_meta.py", line 146, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "/private/var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/pip-build-env-_e3tGk/overlay/lib/python2.7/site-packages/setuptools/build_meta.py", line 127, in _get_build_requires
#       self.run_setup()
#     File "/private/var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/pip-build-env-_e3tGk/overlay/lib/python2.7/site-packages/setuptools/build_meta.py", line 142, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 23, in <module>
#       with open(path.join(this_directory, 'README.md'), encoding='utf-8') as file:
#   TypeError: 'encoding' is an invalid keyword argument for this function
#   ----------------------------------------
# ERROR: Command errored out with exit status 1: /anaconda2/bin/python /anaconda2/lib/python2.7/site-packages/pip/_vendor/pep517/_in_process.py get_requires_for_build_wheel /var/folders/72/d0m8bs5s02s22frkzy08_xlr0000gn/T/tmpaF8Rox Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 20.3.4 is available.
# You should consider upgrading via the '/anaconda2/bin/python -m pip install --upgrade pip' command.

# %%
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ab55dd74d9ce> in <module>()
# ----> 1 from ibm_watson import SpeechToTextV1
#       2 from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
#
# ImportError: No module named ibm_watson

# %%
apikey = '-dBgf9p9XegtLWCCsYg-UlME4SOAI5dMNvuoYPT_2u9v'
url = 'https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/4d4a7d23-4530-45fd-8565-5daf2010a922'
