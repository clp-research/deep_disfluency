# %%
# !pip install ibm_watson
# Out:
# ...
#      |████████████████████████████████| 419kB 3.8MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 71kB 7.2MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 51kB 8.0MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 143kB 8.5MB/s eta 0:00:01
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-5.3.1-cp37-none-any.whl size=409192 sha256=0bffa55baef7c36712b29d7f2aebb9dcad085cc12b5e7c34176f26102631e66b
#   Stored in directory: /Users/julian/Library/Caches/pip/wheels/af/0e/20/7c6f3594ff86f96c96b7edc7482f07e7bd64767b779e4edfc2
# Successfully built ibm-watson
# ...
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.14.0-cp37-none-any.whl size=83267 sha256=45abb0d1736c15de324c5473511b03816f9fa0a391928edc59da2b37bfa6c153
# ...

# %%
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
apikey = '-dBgf9p9XegtLWCCsYg-UlME4SOAI5dMNvuoYPT_2u9v'
url = 'https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/4d4a7d23-4530-45fd-8565-5daf2010a922'

# %%
# Setup Service
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)

# %%
# Perform conversion
with open('Welcome.mp3', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/mp3', model='en-US_NarrowbandModel').get_result()

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'alternatives': [{'confidence': 0.95,
#      'transcript': 'thank you for choosing the Olympus dictation management system '}],
#    'final': True},
#   {'alternatives': [{'confidence': 0.82,
#      'transcript': 'the Olympus dictation management system gives you the power to manage your dictation transcriptions and documents seamlessly and to improve the productivity of your daily work for example you can automatically sends the dictation files %HESITATION transcribe documents your system does the %HESITATION side by email or FTP '}],
#    'final': True},
#   {'alternatives': [{'confidence': 0.91,
#      'transcript': "if you're using the speech recognition software the speech recognition engine works in the background to support your document creation "}],
#    'final': True},
#   {'alternatives': [{'confidence': 0.94,
#      'transcript': 'we hope you enjoy the simple flexible reliable and secure solutions from Olympus '}],
# ...

# %%
print(len(res['results']), "segments")
transcript = ". ".join([res['results'][i]['alternatives'][0]['transcript'].strip() \
                        for i in range(0,len(res['results']))])
transcript
# Out:
# 4 segments
# "thank you for choosing the Olympus dictation management system. the Olympus dictation management system gives you the power to manage your dictation transcriptions and documents seamlessly and to improve the productivity of your daily work for example you can automatically sends the dictation files %HESITATION transcribe documents your system does the %HESITATION side by email or FTP. if you're using the speech recognition software the speech recognition engine works in the background to support your document creation. we hope you enjoy the simple flexible reliable and secure solutions from Olympus"

# %%
with open('output.txt', 'w') as out:
     out.writelines(transcripts)
